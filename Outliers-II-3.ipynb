# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import statistics

# %%
df = sns.load_dataset('tips')
df.head()

# %%
print(np.mean(df['total_bill']))

# %%
print(np.median(df['total_bill']))

# %%
print(statistics.median(df['total_bill']))

# %%
sns.boxplot(df["total_bill"] , orient = 'h')

# %%
sns.histplot(df["total_bill"] , kde = True)
"""This is not normally distributed data as we can see
from the pdf illustrated with the help of kernel density estimator"""

# %%
df1 = sns.load_dataset('iris')

# %%
df1.head()

# %%
sns.histplot(df1["sepal_length"] , kde = True)

# %%
sns.histplot(df1["petal_length"] , kde = True)

# %%
sns.histplot(df1["petal_width"] , kde = True)

# %%
sns.histplot(df1["sepal_width"] , kde = True)
# This graphs looks nrmally distributed due to the symmetrcity

# %%
print(np.mean(df1["sepal_width"]))

# %%
print(np.std(df1["sepal_width"]))

# %%
sns.countplot(df1["species"] , palette = 'pastel' )

# %%
"""Let's do some outlier visualisation through boxplot"""

# %%
Q1 = np.percentile(df1['sepal_length'] ,25)
print(Q1)

# %%
Q3 = np.percentile(df1['sepal_length'] ,75)
print(Q3)

# %%
IQR = Q3 - Q1
print(IQR)

# %%
LOWER_FENCE = Q1 - (1.5*(IQR))
print(LOWER_FENCE)

# %%
UPPER_FENCE = Q3 + (1.5*(IQR))
print(UPPER_FENCE)

# %%
print(np.median(df1['sepal_length']))

# %%
print(np.mean(df1['sepal_length']))

# %%
print(df1["sepal_length"])

# %%
sns.boxplot(df1["sepal_length"])
# IT MEANS THAT THERE IS NO OUTLIER AS WE CAN SEE NO BUBBLE IN THE BOXPLOT !!!
